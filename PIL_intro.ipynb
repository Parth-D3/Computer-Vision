# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
im_file = Image.open('data/page1.jpg')

# %%
im_file.show()

# %%
print(im_file.size)
# Out:
# (3264, 2448)

# %%
print(im_file.format)
# Out:
# JPEG

# %%
print(im_file.mode)
# Out:
# RGB

# %%
plt.imshow(im_file)

# %%
plt.imshow(im_file.rotate(134))

# %%
#im_file.save("--path here--")
